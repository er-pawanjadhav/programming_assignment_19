# %%
def fold(a):
    a=a-1
    a=2**a
    a=a/1000
    return a

f = int(input("enter no of fold : "))
print(f"thickness of Paper folded {f} times is {fold(f)}m ")
# Out:
# enter no of fold : 4
# thickness of Paper folded 4 times is 0.008m
