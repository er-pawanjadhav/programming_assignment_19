# %%
def fun1(l):
    l = list(l)
    l1=[]
    for i in range(len(l)):
        if l[i].isupper():
            l1.append(i)
        else:
            pass
    return l1
            
            
    
a = input("enter string : ")
print(fun1(a), "is list where capital letter available")
# Out:
# enter stringAbcDeFg
# [0, 3, 5] is list where capital letter available
