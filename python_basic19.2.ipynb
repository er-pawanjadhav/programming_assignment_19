# %%
def check(a):
    if a=='True':
        return False
    elif a=='False':
        return True
    else:
        return "boolean expected"
a = input()
print(check(a))
# Out:
# 1
# boolean expected
